# %%
import numpy as np
import pandas as pd

# %%
superstore_df=pd.read_csv(r'C:\Users\HP\Downloads\SampleSuperstore.csv')

# %%
superstore_df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
superstore_df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
superstore_df.shape
# Out:
# (9994, 13)

# %%
superstore_df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
superstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
superstore_df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
print(superstore_df['Category'].unique())
# Out:
# ['Furniture' 'Office Supplies' 'Technology']

# %%
print(superstore_df['State'].unique())
# Out:
# ['Kentucky' 'California' 'Florida' 'North Carolina' 'Washington' 'Texas'
#  'Wisconsin' 'Utah' 'Nebraska' 'Pennsylvania' 'Illinois' 'Minnesota'
#  'Michigan' 'Delaware' 'Indiana' 'New York' 'Arizona' 'Virginia'
#  'Tennessee' 'Alabama' 'South Carolina' 'Oregon' 'Colorado' 'Iowa' 'Ohio'
#  'Missouri' 'Oklahoma' 'New Mexico' 'Louisiana' 'Connecticut' 'New Jersey'
#  'Massachusetts' 'Georgia' 'Nevada' 'Rhode Island' 'Mississippi'
#  'Arkansas' 'Montana' 'New Hampshire' 'Maryland' 'District of Columbia'
#  'Kansas' 'Vermont' 'Maine' 'South Dakota' 'Idaho' 'North Dakota'
#  'Wyoming' 'West Virginia']

# %%
no_of_states=superstore_df['State'].nunique()
print("There are %d states in this df."%no_of_states)
# Out:
# There are 49 states in this df.

# %%
print(superstore_df['Sub-Category'].unique())
# Out:
# ['Bookcases' 'Chairs' 'Labels' 'Tables' 'Storage' 'Furnishings' 'Art'
#  'Phones' 'Binders' 'Appliances' 'Paper' 'Accessories' 'Envelopes'
#  'Fasteners' 'Supplies' 'Machines' 'Copiers']

# %%
no_of_subcategory=superstore_df['Sub-Category'].nunique()
print("Categories are divided into %d subcategories"%no_of_subcategory)
# Out:
# Categories are divided into 17 subcategories

# %%
superstore_df['Segment'].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
 loss_df=superstore_df[superstore_df['Profit'] < 0]

# %%
 loss_df
# Out:
#            Ship Mode      Segment        Country             City  \
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 14    Standard Class  Home Office  United States       Fort Worth
# 15    Standard Class  Home Office  United States       Fort Worth
# 23      Second Class     Consumer  United States     Philadelphia
# 27    Standard Class     Consumer  United States     Philadelphia
# ...              ...          ...            ...              ...
# 9920  Standard Class    Corporate  United States            Bryan
# 9921  Standard Class  Home Office  United States            Akron
# 9931  Standard Class     Consumer  United States   San Bernardino
# 9937    Second Class    Corporate  United States      Los Angeles
# 9962     First Class  Home Office  United States          Houston
#
#              State  Postal Code   Region         Category Sub-Category  \
# 3          Florida        33311    South        Furniture       Tables
# 14           Texas        76106  Central  Office Supplies   Appliances
# 15           Texas        76106  Central  Office Supplies      Binders
# 23    Pennsylvania        19140     East        Furniture       Chairs
# 27    Pennsylvania        19140     East        Furniture    Bookcases
# ...            ...          ...      ...              ...          ...
# 9920         Texas        77803  Central  Office Supplies      Binders
# 9921          Ohio        44312     East  Office Supplies      Binders
# 9931    California        92404     West        Furniture    Bookcases
# 9937    California        90049     West        Furniture       Tables
# 9962         Texas        77041  Central        Furniture    Bookcases
#
#           Sales  Quantity  Discount     Profit
# 3      957.5775         5      0.45  -383.0310
# 14      68.8100         5      0.80  -123.8580
# 15       2.5440         3      0.80    -3.8160
# 23      71.3720         2      0.30    -1.0196
# 27    3083.4300         7      0.50 -1665.0522
# ...         ...       ...       ...        ...
# 9920    22.3860         7      0.80   -35.8176
# 9921     5.7420         3      0.70    -4.5936
# 9931   683.3320         4      0.15   -40.1960
# 9937    71.0880         2      0.20    -1.7772
# 9962   383.4656         4      0.32   -67.6704
#
# [1871 rows x 13 columns]

# %%
Total_loss=np.negative(loss_df['Profit'].sum())
print("Total loss = %.2f" %Total_loss)
# Out:
# Total loss = 156131.29

# %%
loss_df.groupby(by='Segment').sum()
# Out:
#                                                      Ship Mode  \
# Segment
# Consumer     Standard ClassSecond ClassStandard ClassStanda...
# Corporate    First ClassFirst ClassFirst ClassStandard Clas...
# Home Office  Standard ClassStandard ClassStandard ClassStan...
#
#                                                        Country  \
# Segment
# Consumer     United StatesUnited StatesUnited StatesUnited ...
# Corporate    United StatesUnited StatesUnited StatesUnited ...
# Home Office  United StatesUnited StatesUnited StatesUnited ...
#
#                                                           City  \
# Segment
# Consumer     Fort LauderdalePhiladelphiaPhiladelphiaPhilade...
# Corporate    RichardsonHoustonHoustonBristolColumbusChicago...
# Home Office  Fort WorthFort WorthHoustonHoustonChicagoChica...
#
#                                                          State  Postal Code  \
# Segment
# Consumer     FloridaPennsylvaniaPennsylvaniaPennsylvaniaPen...     57202260
# Corporate    TexasTexasTexasTennesseeOhioIllinoisPennsylvan...     30034273
# Home Office  TexasTexasTexasTexasIllinoisIllinoisOregonIlli...     17522858
#
#                                                         Region  \
# Segment
# Consumer     SouthEastEastEastEastSouthSouthCentralWestWest...
# Corporate    CentralCentralCentralSouthEastCentralEastEastE...
# Home Office  CentralCentralCentralCentralCentralCentralWest...
#
#                                                       Category  \
# Segment
# Consumer     FurnitureFurnitureFurnitureOffice SuppliesOffi...
# Corporate    FurnitureOffice SuppliesFurnitureOffice Suppli...
# Home Office  Office SuppliesOffice SuppliesFurnitureFurnitu...
#
#                                                   Sub-Category        Sales  \
# Segment
# Consumer     TablesChairsBookcasesBindersBindersChairsStora...  247196.2460
# Corporate    FurnishingsBindersFurnishingsBindersPhonesAppl...  131860.5383
# Home Office  AppliancesBindersBookcasesChairsChairsStorageB...   89650.3705
#
#              Quantity  Discount      Profit
# Segment
# Consumer         3651    476.76 -84945.7112
# Corporate        2191    272.00 -44787.2076
# Home Office      1198    150.98 -26398.3669

# %%
loss_df.groupby(by='Sub-Category').sum()
# Out:
#                                                       Ship Mode  \
# Sub-Category
# Accessories   Standard ClassStandard ClassStandard ClassStan...
# Appliances    Standard ClassStandard ClassStandard ClassSeco...
# Binders       Standard ClassStandard ClassStandard ClassFirs...
# Bookcases     Standard ClassStandard ClassStandard ClassSeco...
# Chairs        Second ClassStandard ClassStandard ClassStanda...
# Fasteners     Standard ClassFirst ClassStandard ClassStandar...
# Furnishings   First ClassFirst ClassSecond ClassStandard Cla...
# Machines      Standard ClassStandard ClassFirst ClassSecond ...
# Phones        First ClassStandard ClassFirst ClassSecond Cla...
# Storage       Standard ClassFirst ClassStandard ClassStandar...
# Supplies      Second ClassSecond ClassStandard ClassStandard...
# Tables        Standard ClassStandard ClassFirst ClassStandar...
#
#                                                         Segment  \
# Sub-Category
# Accessories   Home OfficeConsumerHome OfficeConsumerConsumer...
# Appliances    Home OfficeConsumerCorporateConsumerConsumerCo...
# Binders       Home OfficeConsumerConsumerCorporateHome Offic...
# Bookcases     ConsumerHome OfficeCorporateHome OfficeConsume...
# Chairs        ConsumerHome OfficeHome OfficeConsumerHome Off...
# Fasteners     CorporateHome OfficeHome OfficeConsumerCorpora...
# Furnishings   CorporateCorporateConsumerConsumerConsumerCons...
# Machines      ConsumerCorporateConsumerCorporateCorporateCor...
# Phones        CorporateCorporateConsumerConsumerConsumerCons...
# Storage       ConsumerHome OfficeConsumerCorporateCorporateC...
# Supplies      ConsumerCorporateHome OfficeConsumerCorporateC...
# Tables        ConsumerConsumerConsumerHome OfficeHome Office...
#
#                                                         Country  \
# Sub-Category
# Accessories   United StatesUnited StatesUnited StatesUnited ...
# Appliances    United StatesUnited StatesUnited StatesUnited ...
# Binders       United StatesUnited StatesUnited StatesUnited ...
# Bookcases     United StatesUnited StatesUnited StatesUnited ...
# Chairs        United StatesUnited StatesUnited StatesUnited ...
# Fasteners     United StatesUnited StatesUnited StatesUnited ...
# Furnishings   United StatesUnited StatesUnited StatesUnited ...
# Machines      United StatesUnited StatesUnited StatesUnited ...
# Phones        United StatesUnited StatesUnited StatesUnited ...
# Storage       United StatesUnited StatesUnited StatesUnited ...
# Supplies      United StatesUnited StatesUnited StatesUnited ...
# Tables        United StatesUnited StatesUnited StatesUnited ...
#
#                                                            City  \
# Sub-Category
# Accessories   ChicagoAuroraTampaTucsonPembroke PinesJacksonv...
# Appliances    Fort WorthSan AntonioChicagoHoustonDallasPasad...
# Binders       Fort WorthPhiladelphiaPhiladelphiaHoustonPortl...
# Bookcases     PhiladelphiaHoustonMedinaColumbusNew York City...
# Chairs        PhiladelphiaHoustonChicagoMemphisHoustonLos An...
# Fasteners     ToledoPhiladelphiaSpringfieldPhiladelphiaPhila...
# Furnishings   RichardsonHoustonHoustonAuroraChicagoChicagoCh...
# Machines      San AntonioMedinaDublinHoustonHoustonPhiladelp...
# Phones        ColumbusMedinaPhiladelphiaPhiladelphiaLos Ange...
# Storage       MemphisChicagoSan AntonioChicagoCincinnatiAust...
# Supplies      NewarkTamaracPhoenixPhiladelphiaChicagoDallasB...
# Tables        Fort LauderdaleBloomingtonDenverTampaTampaChic...
#
#                                                           State  Postal Code  \
# Sub-Category
# Accessories   IllinoisColoradoFloridaArizonaFloridaFloridaOh...      5286382
# Appliances    TexasTexasIllinoisTexasTexasTexasTexasTexasIll...      4825871
# Binders       TexasPennsylvaniaPennsylvaniaTexasOregonIllino...     32609300
# Bookcases     PennsylvaniaTexasOhioOhioNew YorkTexasTexasCal...      6423506
# Chairs        PennsylvaniaTexasIllinoisTennesseeTexasCalifor...     15008025
# Fasteners     OhioPennsylvaniaOregonPennsylvaniaPennsylvania...       701930
# Furnishings   TexasTexasTexasColoradoIllinoisIllinoisIllinoi...     10970913
# Machines      TexasOhioOhioTexasTexasPennsylvaniaNorth Carol...      2236261
# Phones        OhioOhioPennsylvaniaPennsylvaniaCaliforniaOreg...      6105294
# Storage       TennesseeIllinoisTexasIllinoisOhioTexasTexasNo...      8606475
# Supplies      OhioFloridaArizonaPennsylvaniaIllinoisTexasTex...      1761430
# Tables        FloridaIllinoisColoradoFloridaFloridaIllinoisI...     10224004
#
#                                                          Region  \
# Sub-Category
# Accessories   CentralWestSouthWestSouthSouthEastCentralWestW...
# Appliances    CentralCentralCentralCentralCentralCentralCent...
# Binders       CentralEastEastCentralWestCentralWestSouthWest...
# Bookcases     EastCentralEastEastEastCentralCentralWestEastE...
# Chairs        EastCentralCentralSouthCentralWestCentralEastS...
# Fasteners     EastEastWestEastEastWestWestEastWestCentralCen...
# Furnishings   CentralCentralCentralWestCentralCentralCentral...
# Machines      CentralEastEastCentralCentralEastSouthSouthSou...
# Phones        EastEastEastEastWestWestEastEastEastEastEastEa...
# Storage       SouthCentralCentralCentralEastCentralCentralSo...
# Supplies      EastSouthWestEastCentralCentralCentralEastCent...
# Tables        SouthCentralWestSouthSouthCentralCentralWestEa...
#
#                                                        Category        Sales  \
# Sub-Category
# Accessories   TechnologyTechnologyTechnologyTechnologyTechno...   10958.8000
# Appliances    Office SuppliesOffice SuppliesOffice SuppliesO...    3382.5340
# Binders       Office SuppliesOffice SuppliesOffice SuppliesO...   36140.6130
# Bookcases     FurnitureFurnitureFurnitureFurnitureFurnitureF...   48072.7408
# Chairs        FurnitureFurnitureFurnitureFurnitureFurnitureF...   91988.4560
# Fasteners     Office SuppliesOffice SuppliesOffice SuppliesO...     149.2800
# Furnishings   FurnitureFurnitureFurnitureFurnitureFurnitureF...   12845.8440
# Machines      TechnologyTechnologyTechnologyTechnologyTechno...   72456.2530
# Phones        TechnologyTechnologyTechnologyTechnologyTechno...   35797.8400
# Storage       Office SuppliesOffice SuppliesOffice SuppliesO...   37869.0720
# Supplies      Office SuppliesOffice SuppliesOffice SuppliesO...   14067.1760
# Tables        FurnitureFurnitureFurnitureFurnitureFurnitureF...  104978.5460
#
#               Quantity  Discount      Profit
# Sub-Category
# Accessories        330     18.20   -930.6265
# Appliances         235     53.60  -8629.6412
# Binders           2456    452.40 -38510.4964
# Bookcases          422     37.99 -12152.2060
# Chairs             876     61.40  -9880.8413
# Fasteners           55      2.40    -33.1952
# Furnishings        597     88.60  -6490.9134
# Machines           157     25.60 -30118.6682
# Phones             476     46.60  -7530.6235
# Storage            569     32.20  -6426.3038
# Supplies           110      6.60  -3015.6219
# Tables             757     74.15 -32412.1483

# %%
loss_df.groupby(by='City').sum().sort_values('Profit',ascending=True).head(10)
# Out:
#                                                        Ship Mode  \
# City
# Philadelphia   Second ClassStandard ClassStandard ClassStanda...
# Houston        Standard ClassStandard ClassFirst ClassFirst C...
# Chicago        Standard ClassFirst ClassStandard ClassStandar...
# San Antonio    Standard ClassStandard ClassStandard ClassStan...
# Lancaster      Standard ClassSecond ClassStandard ClassStanda...
# Burlington          Same DayStandard ClassStandard ClassSame Day
# Dallas         Second ClassStandard ClassStandard ClassStanda...
# Jacksonville   Standard ClassStandard ClassStandard ClassFirs...
# New York City  Standard ClassFirst ClassSame DaySame DayFirst...
# Louisville     Second ClassStandard ClassStandard ClassStanda...
#
#                                                          Segment  \
# City
# Philadelphia   ConsumerConsumerConsumerConsumerCorporateConsu...
# Houston        Home OfficeHome OfficeCorporateCorporateConsum...
# Chicago        Home OfficeHome OfficeHome OfficeHome OfficeCo...
# San Antonio    ConsumerConsumerConsumerConsumerCorporateCorpo...
# Lancaster      CorporateHome OfficeHome OfficeConsumerConsume...
# Burlington                 CorporateHome OfficeConsumerCorporate
# Dallas         ConsumerConsumerCorporateConsumerConsumerConsu...
# Jacksonville   ConsumerConsumerCorporateConsumerCorporateCorp...
# New York City  ConsumerConsumerConsumerConsumerConsumerConsum...
# Louisville     ConsumerHome OfficeHome OfficeHome OfficeHome ...
#
#                                                          Country  \
# City
# Philadelphia   United StatesUnited StatesUnited StatesUnited ...
# Houston        United StatesUnited StatesUnited StatesUnited ...
# Chicago        United StatesUnited StatesUnited StatesUnited ...
# San Antonio    United StatesUnited StatesUnited StatesUnited ...
# Lancaster      United StatesUnited StatesUnited StatesUnited ...
# Burlington     United StatesUnited StatesUnited StatesUnited ...
# Dallas         United StatesUnited StatesUnited StatesUnited ...
# Jacksonville   United StatesUnited StatesUnited StatesUnited ...
# New York City  United StatesUnited StatesUnited StatesUnited ...
# Louisville     United StatesUnited StatesUnited StatesUnited ...
#
#                                                            State  Postal Code  \
# City
# Philadelphia   PennsylvaniaPennsylvaniaPennsylvaniaPennsylvan...      4783713
# Houston        TexasTexasTexasTexasTexasTexasTexasTexasTexasT...     14256474
# Chicago        IllinoisIllinoisIllinoisIllinoisIllinoisIllino...      9397492
# San Antonio    TexasTexasTexasTexasTexasTexasTexasTexasTexasT...      2580831
# Lancaster      PennsylvaniaOhioOhioPennsylvaniaOhioPennsylvan...       683904
# Burlington     North CarolinaNorth CarolinaNorth CarolinaNort...       108868
# Dallas         TexasTexasTexasTexasTexasTexasTexasTexasTexasT...      5487794
# Jacksonville   FloridaFloridaFloridaFloridaNorth CarolinaNort...      1237176
# New York City  New YorkNew YorkNew YorkNew YorkNew YorkNew Yo...       400828
# Louisville     ColoradoColoradoColoradoColoradoColoradoColora...       640216
#
#                                                           Region  \
# City
# Philadelphia   EastEastEastEastEastEastEastEastEastEastEastEa...
# Houston        CentralCentralCentralCentralCentralCentralCent...
# Chicago        CentralCentralCentralCentralCentralCentralCent...
# San Antonio    CentralCentralCentralCentralCentralCentralCent...
# Lancaster      EastEastEastEastEastEastEastEastEastEastEastEa...
# Burlington                                  SouthSouthSouthSouth
# Dallas         CentralCentralCentralCentralCentralCentralCent...
# Jacksonville   SouthSouthSouthSouthSouthSouthSouthSouthSouthS...
# New York City  EastEastEastEastEastEastEastEastEastEastEastEa...
# Louisville                      WestWestWestWestWestWestWestWest
#
#                                                         Category  \
# City
# Philadelphia   FurnitureFurnitureOffice SuppliesOffice Suppli...
# Houston        FurnitureFurnitureOffice SuppliesFurnitureFurn...
# Chicago        FurnitureOffice SuppliesTechnologyOffice Suppl...
# San Antonio    TechnologyOffice SuppliesFurnitureOffice Suppl...
# Lancaster      Office SuppliesFurnitureTechnologyOffice Suppl...
# Burlington           TechnologyOffice SuppliesFurnitureFurniture
# Dallas         Office SuppliesOffice SuppliesOffice SuppliesO...
# Jacksonville   Office SuppliesTechnologyFurnitureOffice Suppl...
# New York City  FurnitureFurnitureFurnitureFurnitureFurnitureF...
# Louisville     FurnitureOffice SuppliesTechnologyOffice Suppl...
#
#                                                     Sub-Category       Sales  \
# City
# Philadelphia   ChairsBookcasesBindersBindersBindersPhonesChai...  70460.5510
# Houston        BookcasesChairsBindersFurnishingsFurnishingsCh...  37640.7304
# Chicago        ChairsStorageAccessoriesBindersAppliancesFurni...  19910.0120
# San Antonio    MachinesStorageChairsAppliancesTablesChairsBin...  17395.1450
# Lancaster      BindersTablesPhonesSuppliesAccessoriesBindersP...   7699.2420
# Burlington                           MachinesBindersTablesTables  12044.8740
# Dallas         AppliancesSuppliesStorageBindersAppliancesBind...   9994.0562
# Jacksonville   BindersAccessoriesTablesBindersMachinesBinders...  31146.2710
# New York City  BookcasesBookcasesTablesTablesTablesTablesBook...  19533.8020
# Louisville     TablesBindersMachinesBindersBindersBindersBook...   2884.7840
#
#                Quantity  Discount      Profit
# City
# Philadelphia        892    115.30 -19590.7411
# Houston             683    104.14 -14785.3668
# Chicago             541     88.20 -11120.6271
# San Antonio         139     17.10  -7831.0254
# Lancaster            71      9.40  -7632.4946
# Burlington           19      2.00  -5999.3318
# Dallas              280     39.30  -4208.5218
# Jacksonville        154     18.85  -4059.9857
# New York City       132     12.20  -3966.0226
# Louisville           35      4.90  -3694.1045

# %%
superstore_df.groupby(['State']).sum()['Sales'].nsmallest(10)
# Out:
# State
# North Dakota             919.910
# West Virginia           1209.824
# Maine                   1270.530
# South Dakota            1315.560
# Wyoming                 1603.136
# District of Columbia    2865.020
# Kansas                  2914.310
# Idaho                   4382.486
# Iowa                    4579.760
# New Mexico              4783.522
# Name: Sales, dtype: float64

# %%
superstore_df.sort_values(['Segment'],ascending=True).groupby('Segment').sum()
# Out:
#                                                      Ship Mode  \
# Segment
# Consumer     Second ClassStandard ClassStandard ClassStanda...
# Corporate    Second ClassStandard ClassFirst ClassSecond Cl...
# Home Office  Standard ClassStandard ClassSecond ClassStanda...
#
#                                                        Country  \
# Segment
# Consumer     United StatesUnited StatesUnited StatesUnited ...
# Corporate    United StatesUnited StatesUnited StatesUnited ...
# Home Office  United StatesUnited StatesUnited StatesUnited ...
#
#                                                           City  \
# Segment
# Consumer     HendersonChicagoSan FranciscoSmyrnaLos Angeles...
# Corporate    HoustonSan FranciscoArlingtonChicagoPhiladelph...
# Home Office  New York CityLos AngelesHendersonSan Francisco...
#
#                                                          State  Postal Code  \
# Segment
# Consumer     KentuckyIllinoisCaliforniaGeorgiaCaliforniaNew...    288878609
# Corporate    TexasCaliforniaVirginiaIllinoisPennsylvaniaCal...    164536330
# Home Office  New YorkCaliforniaKentuckyCaliforniaFloridaNew...     98157713
#
#                                                         Region  \
# Segment
# Consumer     SouthCentralWestSouthWestEastEastEastEastEastE...
# Corporate    CentralWestSouthCentralEastWestWestSouthEastWe...
# Home Office  EastWestSouthWestSouthEastWestCentralWestEastE...
#
#                                                       Category  \
# Segment
# Consumer     FurnitureOffice SuppliesFurnitureOffice Suppli...
# Corporate    FurnitureTechnologyOffice SuppliesOffice Suppl...
# Home Office  FurnitureOffice SuppliesOffice SuppliesOffice ...
#
#                                                   Sub-Category         Sales  \
# Segment
# Consumer     BookcasesPaperFurnishingsEnvelopesPaperPaperCh...  1.161401e+06
# Corporate    ChairsPhonesStorageStorageEnvelopesBindersEnve...  7.061464e+05
# Home Office  TablesArtEnvelopesBindersStoragePaperPaperPhon...  4.296531e+05
#
#              Quantity  Discount       Profit
# Segment
# Consumer        19521    820.91  134119.2092
# Corporate       11608    477.85   91979.1340
# Home Office      6744    262.33   60298.6785

# %%
superstore_df.groupby(by='Region').sum()
# Out:
#                                                  Ship Mode  \
# Region
# Central  Standard ClassStandard ClassStandard ClassStan...
# East     Second ClassStandard ClassStandard ClassStanda...
# South    Second ClassSecond ClassStandard ClassStandard...
# West     Second ClassStandard ClassStandard ClassStanda...
#
#                                                    Segment  \
# Region
# Central  Home OfficeHome OfficeConsumerCorporateCorpora...
# East     ConsumerConsumerConsumerConsumerConsumerConsum...
# South    ConsumerConsumerConsumerConsumerConsumerCorpor...
# West     CorporateConsumerConsumerConsumerConsumerConsu...
#
#                                                    Country  \
# Region
# Central  United StatesUnited StatesUnited StatesUnited ...
# East     United StatesUnited StatesUnited StatesUnited ...
# South    United StatesUnited StatesUnited StatesUnited ...
# West     United StatesUnited StatesUnited StatesUnited ...
#
#                                                       City  \
# Region
# Central  Fort WorthFort WorthMadisonFremontFremontHoust...
# East     PhiladelphiaPhiladelphiaPhiladelphiaPhiladelph...
# South    HendersonHendersonFort LauderdaleFort Lauderda...
# West     Los AngelesLos AngelesLos AngelesLos AngelesLo...
#
#                                                      State  Postal Code  \
# Region
# Central  TexasTexasWisconsinNebraskaNebraskaTexasTexasT...    151786150
# East     PennsylvaniaPennsylvaniaPennsylvaniaPennsylvan...     50171698
# South    KentuckyKentuckyFloridaFloridaNorth CarolinaFl...     55875052
# West     CaliforniaCaliforniaCaliforniaCaliforniaCalifo...    293739752
#
#                                                   Category  \
# Region
# Central  Office SuppliesOffice SuppliesOffice SuppliesO...
# East     FurnitureFurnitureOffice SuppliesFurnitureOffi...
# South    FurnitureFurnitureFurnitureOffice SuppliesOffi...
# West     Office SuppliesFurnitureOffice SuppliesTechnol...
#
#                                               Sub-Category        Sales  \
# Region
# Central  AppliancesBindersStorageArtAppliancesPaperPhon...  501239.8908
# East     ChairsBookcasesBindersFurnishingsEnvelopesArtB...  678781.2400
# South    BookcasesChairsTablesStoragePaperStoragePaperC...  391721.9050
# West     LabelsFurnishingsArtPhonesBindersAppliancesTab...  725457.8245
#
#          Quantity  Discount       Profit
# Region
# Central      8780    558.34   39706.3625
# East        10618    414.00   91522.7800
# South        6209    238.55   46749.4303
# West        12266    350.20  108418.4489

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize']=(15,3)
plt.bar(loss_df['Sub-Category'],loss_df['Sales']);
plt.rcParams.update({'font.size':10});
plt.xlabel('Sub_Category');
plt.ylabel('Sales');

# %%
plt.rcParams['figure.figsize']=(10,8)
plt.bar(superstore_df['Ship Mode'],superstore_df['Sales']);
plt.rcParams.update({'font.size':14});
plt.xlabel('Ship Mode');
plt.ylabel('Sales');

# %%
import seaborn as sns
plt.rcParams['figure.figsize']=(10,5)
sns.countplot(x=superstore_df.Segment)
plt.show();

# %%
plt.rcParams['figure.figsize']=(20,5)
plt.rcParams.update({'font.size':12})
sns.countplot(x='Sub-Category',data=superstore_df)
plt.show()

# %%
plt.rcParams['figure.figsize']=(20,5)
plt.rcParams.update({'font.size':12})
sns.countplot(x='Region',data=superstore_df)
plt.show()

# %% [markdown]
# Here we can see south region needs more improvement compared to others.
